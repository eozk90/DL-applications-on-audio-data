# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
from random import random
#CPU version
import tensorflow as tf 
from sklearn.model_selection import train_test_split



def generate_dataset(num_samples, test_size):
    #create a dataset to train a network for the sum operation
    #list comprehension
    #array([[0.1, 0.2], [0.3,0.4]])
    x = np.array([[random() / 2 for _ in range(2)] for _ in range(num_samples)])
    #array([[0.3],[0.7])
    y = np.array([[i[0] + i[1]] for i in x])
    x_train, x_test, y_train, y_test = train_test_split(x ,y, test_size = test_size)
    return x_train, x_test, y_train, y_test

if __name__ == "__main__":
    x_train, x_test, y_train, y_test = generate_dataset(5000,0.3)
    print("x_test: \n {}".format(x_test))
    print("y_test: \n {}".format(y_test))
    
    #build model: 2 -> 5 -> 1
    #keras is a high level library that sits on top of tensorflow
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(5, input_dim = 2, activation = "sigmoid"),
        tf.keras.layers.Dense(1, activation = "sigmoid")
    ])
    
    #compile the model
    optimizer = tf.keras.optimizers.SGD(learning_rate = 0.1)
    model.compile(optimizer = optimizer, loss = "MSE")
    
    #train model
    model.fit(x_train, y_train, epochs = 100)

    #evaluate model
    print("\nModel evaluation")
    model.evaluate(x_test, y_test, verbose=True)
    
    #make predictions
    data = np.array([[0.112, 0.245], [0.22,0.34]])
    predictions = model.predict(data)
    
    
    print("\nSome predictions: ")
    for d, p in zip(data,predictions):
        print("{} + {} = {}".format(d[0], d[1], p[0]))
# Out:
# x_test:
#  [[0.25191012 0.10448258]
#  [0.13924263 0.48099688]
#  [0.38310336 0.45342404]
#  ...
#  [0.02911909 0.03387246]
#  [0.1435098  0.49156796]
#  [0.36140214 0.15845179]]
# y_test:
#  [[0.3563927 ]
#  [0.62023952]
#  [0.8365274 ]
#  ...
#  [0.06299154]
#  [0.63507775]
#  [0.51985394]]
# Epoch 1/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0402
# Epoch 2/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0396
# Epoch 3/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0392
# Epoch 4/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0388
# Epoch 5/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0384
# Epoch 6/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0379
# Epoch 7/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0375
# Epoch 8/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0370
# Epoch 9/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0365
# Epoch 10/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0361
# Epoch 11/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0356
# Epoch 12/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0350
# Epoch 13/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0345
# Epoch 14/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0339
# Epoch 15/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0334
# Epoch 16/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 17/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0322
# Epoch 18/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0315
# Epoch 19/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0309
# Epoch 20/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0302
# Epoch 21/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0295
# Epoch 22/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0288
# Epoch 23/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0280
# Epoch 24/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 25/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 26/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0258
# Epoch 27/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0250
# Epoch 28/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0242
# Epoch 29/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 30/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0225
# Epoch 31/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0217
# Epoch 32/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0209
# Epoch 33/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0201
# Epoch 34/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0193
# Epoch 35/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0185
# Epoch 36/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0177
# Epoch 37/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0169
# Epoch 38/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0161
# Epoch 39/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 40/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0146
# Epoch 41/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0138
# Epoch 42/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 43/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 44/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0118
# Epoch 45/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 46/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0105
# Epoch 47/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0099
# Epoch 48/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0093
# Epoch 49/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 50/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0083
# Epoch 51/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 52/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0073
# Epoch 53/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 54/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 55/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 56/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0057
# Epoch 57/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 58/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 59/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 60/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 61/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 62/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 63/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0036
# Epoch 64/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 65/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 66/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 67/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 68/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 69/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 70/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 71/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 72/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 73/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 74/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 75/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 76/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 77/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 78/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 79/100
# 110/110 [==============================] - 0s 990us/step - loss: 0.0014
# Epoch 80/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 81/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 82/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 83/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 84/100
# 110/110 [==============================] - 0s 862us/step - loss: 0.0011
# Epoch 85/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 86/100
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 87/100
# 110/110 [==============================] - 0s 1ms/step - loss: 9.5977e-04
# Epoch 88/100
# 110/110 [==============================] - 0s 869us/step - loss: 9.2045e-04
# Epoch 89/100
# 110/110 [==============================] - 0s 1ms/step - loss: 8.8392e-04
# Epoch 90/100
# 110/110 [==============================] - 0s 918us/step - loss: 8.4982e-04
# Epoch 91/100
# 110/110 [==============================] - 0s 968us/step - loss: 8.1826e-04
# Epoch 92/100
# 110/110 [==============================] - 0s 968us/step - loss: 7.8876e-04
# Epoch 93/100
# 110/110 [==============================] - 0s 942us/step - loss: 7.6169e-04
# Epoch 94/100
# 110/110 [==============================] - 0s 906us/step - loss: 7.3644e-04
# Epoch 95/100
# 110/110 [==============================] - 0s 981us/step - loss: 7.1299e-04
# Epoch 96/100
# 110/110 [==============================] - 0s 815us/step - loss: 6.9127e-04
# Epoch 97/100
# 110/110 [==============================] - 0s 874us/step - loss: 6.7104e-04
# Epoch 98/100
# 110/110 [==============================] - 0s 1ms/step - loss: 6.5198e-04
# Epoch 99/100
# 110/110 [==============================] - 0s 2ms/step - loss: 6.3488e-04
# Epoch 100/100
# 110/110 [==============================] - 0s 3ms/step - loss: 6.1855e-04
#
# Model evaluation
# 47/47 [==============================] - 0s 1ms/step - loss: 5.9622e-04
#
# Some predictions:
# 0.112 + 0.245 = 0.35660475492477417
# 0.22 + 0.34 = 0.5696184039115906
