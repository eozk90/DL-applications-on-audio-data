# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

data_path = "genres/data.json"


def load_data(dataset_path):
    """
    Loads training dataset from json file
    :param data_path (str): Path to json file containing data
    :return X (ndarray): Inputs
    :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    #convert lists into numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    return X, y


def prepare_datasets(test_size, validation_size):

    #load data
    X, y = load_data(data_path)

    #create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X,
                                                        y,
                                                        test_size=test_size)

    #create train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(
        X_train, y_train, test_size=validation_size)

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generate RNN-LSTM model"""

    #create model
    model = keras.Sequential()

    #2 LSTM layers
    model.add(
        keras.layers.LSTM(64, input_shape=input_shape, return_sequences=True))
    model.add(keras.layers.LSTM(64))

    #dense layer
    model.add(keras.layers.Dense(64, activation='relu'))
    #to mitigate the overfitting issue
    model.add(keras.layers.Dropout(0.3))

    #output layer uses softmax
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


def predict(model, X, y):

    X = X[np.newaxis, ...]

    #expects a 4d array
    #prediction is a 2D array = [[0.1, 0.2, ...]] 10 different scores
    prediction = model.predict(X)  # X->(1 (# of sample),130,13,1)

    #extract the index with max value
    predicted_index = np.argmax(prediction, axis=1)  #[3] index predicted
    print("Expected index: {}, Predicted index{}".format(y, predicted_index))


if __name__ == "__main__":

    #create train, validation, and test sets
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(
        0.25, 0.2)

    #create network
    input_shape = (X_train.shape[1], X_train.shape[2])  #130,13
    model = build_model(input_shape)

    #compile the network
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    model.summary()

    #train the model
    history = model.fit(X_train,
                        y_train,
                        validation_data=(X_validation, y_validation),
                        batch_size=32,
                        epochs=30)

    #evaluate the model on test set
    test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
    print("Accuracy on test set is {}".format(test_accuracy))

    #make prediction on a sample
    X = X_test[100]
    y = y_test[100]

    predict(model, X, y)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 130, 64)           19968
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 57,802
# Trainable params: 57,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 188/188 [==============================] - 25s 117ms/step - loss: 2.2143 - accuracy: 0.1739 - val_loss: 2.0923 - val_accuracy: 0.2687
# Epoch 2/30
# 188/188 [==============================] - 24s 127ms/step - loss: 1.9933 - accuracy: 0.2985 - val_loss: 1.8625 - val_accuracy: 0.3600
# Epoch 3/30
# 188/188 [==============================] - 24s 128ms/step - loss: 1.7846 - accuracy: 0.3732 - val_loss: 1.6820 - val_accuracy: 0.4220
# Epoch 4/30
# 188/188 [==============================] - 31s 163ms/step - loss: 1.6687 - accuracy: 0.4187 - val_loss: 1.5869 - val_accuracy: 0.4527
# Epoch 5/30
# 188/188 [==============================] - 35s 184ms/step - loss: 1.5885 - accuracy: 0.4419 - val_loss: 1.5029 - val_accuracy: 0.4773
# Epoch 6/30
# 188/188 [==============================] - 35s 187ms/step - loss: 1.5138 - accuracy: 0.4622 - val_loss: 1.4542 - val_accuracy: 0.4820
# Epoch 7/30
# 188/188 [==============================] - 28s 150ms/step - loss: 1.4540 - accuracy: 0.4961 - val_loss: 1.4083 - val_accuracy: 0.5047
# Epoch 8/30
# 188/188 [==============================] - 26s 139ms/step - loss: 1.3936 - accuracy: 0.5091 - val_loss: 1.3746 - val_accuracy: 0.5100
# Epoch 9/30
# 188/188 [==============================] - 28s 150ms/step - loss: 1.3675 - accuracy: 0.5199 - val_loss: 1.3444 - val_accuracy: 0.5287
# Epoch 10/30
# 188/188 [==============================] - 28s 152ms/step - loss: 1.3435 - accuracy: 0.5264 - val_loss: 1.3391 - val_accuracy: 0.5307
# Epoch 11/30
# 188/188 [==============================] - 26s 141ms/step - loss: 1.3244 - accuracy: 0.5388 - val_loss: 1.2950 - val_accuracy: 0.5387
# Epoch 12/30
# 188/188 [==============================] - 25s 136ms/step - loss: 1.2726 - accuracy: 0.5568 - val_loss: 1.2821 - val_accuracy: 0.5500
# Epoch 13/30
# 188/188 [==============================] - 29s 156ms/step - loss: 1.3191 - accuracy: 0.5381 - val_loss: 1.3138 - val_accuracy: 0.5347
# Epoch 14/30
# 188/188 [==============================] - 43s 228ms/step - loss: 1.2486 - accuracy: 0.5671 - val_loss: 1.2664 - val_accuracy: 0.5467
# Epoch 15/30
# 188/188 [==============================] - 27s 146ms/step - loss: 1.2414 - accuracy: 0.5763 - val_loss: 1.2589 - val_accuracy: 0.5473
# Epoch 16/30
# 188/188 [==============================] - 29450s 157s/step - loss: 1.2042 - accuracy: 0.5830 - val_loss: 1.2335 - val_accuracy: 0.5593
# Epoch 17/30
# 188/188 [==============================] - 25s 135ms/step - loss: 1.1731 - accuracy: 0.5955 - val_loss: 1.2616 - val_accuracy: 0.5567
# Epoch 18/30
# 188/188 [==============================] - 29s 153ms/step - loss: 1.1796 - accuracy: 0.5978 - val_loss: 1.2055 - val_accuracy: 0.5720
# Epoch 19/30
# 188/188 [==============================] - 28s 151ms/step - loss: 1.1839 - accuracy: 0.5880 - val_loss: 1.2035 - val_accuracy: 0.5820
# Epoch 20/30
# 188/188 [==============================] - 32s 168ms/step - loss: 1.1325 - accuracy: 0.6075 - val_loss: 1.2422 - val_accuracy: 0.5613
# Epoch 21/30
# 188/188 [==============================] - 34s 182ms/step - loss: 1.1228 - accuracy: 0.6191 - val_loss: 1.1866 - val_accuracy: 0.5840
# Epoch 22/30
# 188/188 [==============================] - 30s 158ms/step - loss: 1.0852 - accuracy: 0.6251 - val_loss: 1.1753 - val_accuracy: 0.5860
# Epoch 23/30
# 188/188 [==============================] - 30s 159ms/step - loss: 1.0712 - accuracy: 0.6285 - val_loss: 1.1584 - val_accuracy: 0.5987
# Epoch 24/30
# 188/188 [==============================] - 29s 157ms/step - loss: 1.0532 - accuracy: 0.6385 - val_loss: 1.1625 - val_accuracy: 0.5947
# Epoch 25/30
# 188/188 [==============================] - 33s 175ms/step - loss: 1.0408 - accuracy: 0.6450 - val_loss: 1.1590 - val_accuracy: 0.5973
# Epoch 26/30
# 188/188 [==============================] - 29s 156ms/step - loss: 1.0211 - accuracy: 0.6535 - val_loss: 1.1927 - val_accuracy: 0.5933
# Epoch 27/30
# 188/188 [==============================] - 30s 159ms/step - loss: 1.0147 - accuracy: 0.6540 - val_loss: 1.1582 - val_accuracy: 0.5947
# Epoch 28/30
# 188/188 [==============================] - 29s 157ms/step - loss: 1.0616 - accuracy: 0.6382 - val_loss: 1.1852 - val_accuracy: 0.5933
# Epoch 29/30
# 188/188 [==============================] - 29s 156ms/step - loss: 1.0214 - accuracy: 0.6470 - val_loss: 1.1410 - val_accuracy: 0.5980
# Epoch 30/30
# 188/188 [==============================] - 29s 157ms/step - loss: 0.9939 - accuracy: 0.6575 - val_loss: 1.1504 - val_accuracy: 0.6033
# 79/79 [==============================] - 4s 47ms/step - loss: 1.1501 - accuracy: 0.6066
# Accuracy on test set is 0.6066426634788513
# Expected index: 8, Predicted index[6]
